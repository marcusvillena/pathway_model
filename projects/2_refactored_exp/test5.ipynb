# %%
from modules.utils import clean_name
import itertools

# %%
def kwarg_grid(**param_lists):
    keys = param_lists.keys()
    param_grid = []

    for values in itertools.product(*param_lists.values()):
        params = dict(zip(keys, values))
        param_grid.append(params)

    return param_grid

# %%
kwarg_grid(alpha=[0.1, 0.01], beta=[0.5, 0.9])
# Out:
# [{'alpha': 0.1, 'beta': 0.5},
#  {'alpha': 0.1, 'beta': 0.9},
#  {'alpha': 0.01, 'beta': 0.5},
#  {'alpha': 0.01, 'beta': 0.9}]
