# %%
from modules.viz import MultiExperiment, metric_x_point, devplot
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# grid = MultiExperiment(
#     experiment_dirs=['output/2026-01-04_11h37m47s_grid_5a_NBreconstr_multihead'],
#     keys=['embed_dim','num_heads','aggregate'],
#     out_dir='./experiments/grid_5a_NBreconstr_multihead',
#     overwrite=True
# )

grid = MultiExperiment(
    experiment_dirs=['./output/2026-01-14_15h28m49s_grid_5b_multilatent_multihead_v_setpool'],
    keys=['pooling_class','num_heads','aggregate'],
    out_dir='./experiments/grid_5b_NBreconstr_multihead_v_setpool',
    overwrite=True
)

# %%
metric_x_point(
    df=grid.test,
    cols=grid.keys,
    metrics=['mae_ae','nb_ae', 'accuracy_cl'],
    figsize=(12,7),
    strip=True,
    sig=True,
    # hue=True,
)
