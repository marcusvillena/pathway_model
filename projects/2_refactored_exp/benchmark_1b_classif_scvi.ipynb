# %%
import modules.data_scvi as d 
import modules.utils as u
from pathlib import Path

#### init ####
dataset_dir = Path('/home/mv18gs/Documents/GitHub/pathway_model/datasets/')
device = u.Devices().auto_set_device()#drop=['cuda:4','cuda:7'])
# Out:
# ('cuda:1', 'NVIDIA A100-SXM4-80GB', 81043)
# ('cuda:6', 'NVIDIA A100-SXM4-80GB', 81043)
# ('cuda:7', 'NVIDIA A100-SXM4-80GB', 81041)
# ('cuda:0', 'NVIDIA A100-SXM4-80GB', 78941)
# ('cuda:5', 'NVIDIA A100-SXM4-80GB', 74623)
# ('cuda:4', 'NVIDIA A100-SXM4-80GB', 59067)
# ('cuda:3', 'NVIDIA A100-SXM4-80GB', 8741)
# ('cuda:2', 'NVIDIA A100-SXM4-80GB', 8731)
#
# # #### Device() ####
# # device = cuda:1

# %% [markdown]
# ---

# %%
from modules.layers import AttentionSetPooling
from modules.loss import MultiLoss, NBLoss, KLDLoss
from modules.model import BaseClassifier, MultiLatentModel
from modules.norm import LogCounts
from modules.train import Experiment, grid
from modules.trainers import ReconstrTrainer, ClassifTrainer

from functools import partial
import torch.nn as nn

# %%
#### data ####
datasets = {
    'cortex': d.scviData(
        dataset='cortex', # cortex, pbmc_dataset
        dataset_dir=dataset_dir / 'scvi',
        x_label_col='index',
        x_label_type='name', # name, ensg
        y_label_col='cell_type',
        gene_name_path=dataset_dir/'other'/'name2ensg.csv',
    ),

    'pbmc_dataset': d.scviData(
        dataset='pbmc_dataset', # cortex, pbmc_dataset
        dataset_dir=dataset_dir / 'scvi',
        x_label_col='index',
        x_label_type='ensg', # name, ensg
        y_label_col='str_labels', # cell_type, str_labels
        gene_name_path=dataset_dir/'other'/'name2ensg.csv',
    ),
}
# Out:
# INFO     File /home/mv18gs/Documents/GitHub/pathway_model/datasets/scvi/cortex/expression.bin already downloaded
# INFO     Loading Cortex data from /home/mv18gs/Documents/GitHub/pathway_model/datasets/scvi/cortex/expression.bin
# INFO     Finished loading Cortex data
# /home/mv18gs/miniconda3/envs/thesis_scvi/lib/python3.14/functools.py:982: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# INFO     File /home/mv18gs/Documents/GitHub/pathway_model/datasets/scvi/pbmc_dataset/gene_info_pbmc.csv already
#          downloaded
# INFO     File /home/mv18gs/Documents/GitHub/pathway_model/datasets/scvi/pbmc_dataset/pbmc_metadata.pickle already
#          downloaded
# INFO     File
#          /home/mv18gs/Documents/GitHub/pathway_model/datasets/scvi/pbmc_dataset/pbmc8k/filtered_gene_bc_matrices.ta
#          r.gz already downloaded
# INFO     Extracting tar file
# INFO     Removing extracted data at
#          /home/mv18gs/Documents/GitHub/pathway_model/datasets/scvi/pbmc_dataset/pbmc8k/filtered_gene_bc_matrices
# INFO     File
#          /home/mv18gs/Documents/GitHub/pathway_model/datasets/scvi/pbmc_dataset/pbmc4k/filtered_gene_bc_matrices.ta
#          r.gz already downloaded
# INFO     Extracting tar file
# INFO     Removing extracted data at
#          /home/mv18gs/Documents/GitHub/pathway_model/datasets/scvi/pbmc_dataset/pbmc4k/filtered_gene_bc_matrices
# /home/mv18gs/miniconda3/envs/thesis_scvi/lib/python3.14/site-packages/scvi/data/_built_in_data/_pbmc.py:75: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata = pbmc8k.concatenate(pbmc4k)

# %%
def run_expt(counts_name:str, counts_data:d.TCGA, num_trials:int=5):
    # data
    kegg = d.KEGG(
        relation_filepath=dataset_dir/'other'/'relation_ohe.csv', 
        counts_data=counts_data,
    )
    dataset = d.GraphDataset(counts_data, kegg, kegg)

    # models
    glm = MultiLatentModel(
        dataset=dataset,
        embed_dim = 128,
        method='node', # !!!

        norm_class = LogCounts,
        encoder_class = nn.Linear,
        pooling_class = AttentionSetPooling,
        mlp = False,
        variational = False, # !!!

        hidden_dims = 0, # !!!
        act_fn = nn.ReLU, 
        norm_fn = 'layer', 
        end_fn = False,

        norm_kwargs = {'libnorm':True, 'znorm':True, 'learnable':True,}
    )

    vae = MultiLatentModel(
        dataset=dataset,
        embed_dim = 128,
        method='node', # !!!

        norm_class = LogCounts,
        encoder_class = nn.Linear,
        pooling_class = AttentionSetPooling,
        mlp = False,
        variational = False, # !!!

        hidden_dims = 1, # !!!
        act_fn = nn.ReLU, 
        norm_fn = 'layer', 
        end_fn = False,

        norm_kwargs = {'libnorm':True, 'znorm':True, 'learnable':True,}
    )

    pvae = MultiLatentModel(
        dataset=dataset,
        embed_dim = 128,
        method='set', # !!!


        norm_class = LogCounts,
        encoder_class = nn.Linear,
        pooling_class = AttentionSetPooling,
        mlp = False,
        variational = False, # !!!

        hidden_dims = 1, # !!!
        act_fn = nn.ReLU, 
        norm_fn = 'layer', 
        end_fn = False,

        norm_kwargs = {'libnorm':True, 'znorm':True, 'learnable':True,}
    )

    # trainer
    trainer = ClassifTrainer(
        lr=1e-3, 

        early_stop=True,
        stop_metric='accuracy',
        stop_kwargs={'mode':'max'},

        kw_keys={'input':'y_logits', 'target':'y'},
        metric_keys={'pred':'input', 'target':'target'},
        loss_class=nn.CrossEntropyLoss,
    )
    
    # expt
    expt = Experiment(
        num_trials=num_trials, # scVI: 5 trials
        num_epochs=300, # scVI: 200 epochs
        dataset=dataset,
        device=device,
        batch_size=128
    )

    expt.add_config(
        name='gene-linear',
        model=glm,
        trainer=trainer,
    )

    expt.add_config(
        name='gene-vae',
        model=vae,
        trainer=trainer,
    )

    expt.add_config(
        name='pathway-vae',
        model=pvae,
        trainer=trainer,
    )

    expt.run_experiment(
        f'benchmark_1b_classif_scvi_{counts_name}',
        report_metrics=['loss','kld','nb','mae', 'accuracy', 'precision', 'f1'],
        save_model=True,
        save_csv=True,
        save_params=True,
        save_values=True,
        verbose=False,
    )

# %%
for k,v in datasets.items():
    run_expt(k, v, num_trials=25)

# for k,v in datasets.items():
#     run_expt(k, v, num_trials=25)

# for k,v in datasets.items():
#     run_expt(k, v, num_trials=20)

# for some reason running again causes a bug, like re-initializing the dataset is needed
# Out:
# # #### KEGG() ####
# # _orig_kwargs             5                        dict
# # relation                 (75939, 19)              DataFrame
# # ensg                     3688                     list
# # pathway_labels           305                      list
# # edge_index               (2, 26946)               Tensor (cuda:1)
# # edge_attr                (26946, 16)              Tensor (cuda:1)
# # edge_labels              16                       list
# # pathway_index            (3688, 305)              Tensor (cuda:1)
#
# # #### scviData() ####
# # _orig_kwargs             8                        dict
# # verbose                  True                     bool
# # adata                    AnnData
# # x_names                  (3688, 3)                DataFrame
# # ensg_complete            14404                    list
# # x_labels                 19972                    list
# # y                        (3005,)                  Tensor (cuda:1)
# # y_labels                 7                        list
# # x                        (3005, 3688, 1)          Tensor (cuda:1)
#
# # #### DataWrapper() ####
# # counts_params            8                        dict
# # edge_params              5                        dict
# # pathway_params           NoneType
# # x                        (3005, 3688, 1)          Tensor (cuda:1)
# # y                        (3005,)                  Tensor (cuda:1)
# # x_labels                 19972                    list
# # y_labels                 7                        list
# # edge_index               (2, 26946)               Tensor (cuda:1)
# # edge_attr                (26946, 16)              Tensor (cuda:1)
# # edge_labels              16                       list
# # pathway_index            (3688, 305)              Tensor (cuda:1)
# # pathway_labels           305                      list
# # num_samples              3005                     int
# # num_nodes                3688                     int
# # num_node_features        1                        int
# # num_classes              7                        int
# # num_edges                26946                    int
# # num_edge_features        16                       int
# # num_pathways             305                      int
#
#
# # #### GraphDataset(), Summary ####
# # Average node degree      0.1369                   float
# # Has isolated nodes       True                     bool
# # Has self-loops           True                     bool
# # Directionality           directed                 str
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
# # #### KEGG() ####
# # _orig_kwargs             5                        dict
# # relation                 (75939, 19)              DataFrame
# # ensg                     1098                     list
# # pathway_labels           305                      list
# # edge_index               (2, 2117)                Tensor (cuda:1)
# # edge_attr                (2117, 16)               Tensor (cuda:1)
# # edge_labels              16                       list
# # pathway_index            (1098, 305)              Tensor (cuda:1)
#
# # #### scviData() ####
# # _orig_kwargs             8                        dict
# # verbose                  True                     bool
# # adata                    AnnData
# # x_names                  (1098, 7)                DataFrame
# # ensg_complete            3337                     list
# # x_labels                 3346                     list
# # y                        (11990,)                 Tensor (cuda:1)
# # y_labels                 9                        list
# # x                        (11990, 1098, 1)         Tensor (cuda:1)
#
# # #### DataWrapper() ####
# # counts_params            8                        dict
# # edge_params              5                        dict
# # pathway_params           NoneType
# # x                        (11990, 1098, 1)         Tensor (cuda:1)
# # y                        (11990,)                 Tensor (cuda:1)
# # x_labels                 3346                     list
# # y_labels                 9                        list
# # edge_index               (2, 2117)                Tensor (cuda:1)
# # edge_attr                (2117, 16)               Tensor (cuda:1)
# # edge_labels              16                       list
# # pathway_index            (1098, 305)              Tensor (cuda:1)
# # pathway_labels           305                      list
# # num_samples              11990                    int
# # num_nodes                1098                     int
# # num_node_features        1                        int
# # num_classes              9                        int
# # num_edges                2117                     int
# # num_edge_features        16                       int
# # num_pathways             305                      int
#
#
# # #### GraphDataset(), Summary ####
# # Average node degree      0.5187                   float
# # Has isolated nodes       True                     bool
# # Has self-loops           True                     bool
# # Directionality           directed                 str
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
# /home/mv18gs/Documents/GitHub/pathway_model/projects/2_refactored_exp/modules/train.py:840: SmallSampleWarning: After omitting NaNs, one or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   sem = stats.sem(series, nan_policy='omit')
