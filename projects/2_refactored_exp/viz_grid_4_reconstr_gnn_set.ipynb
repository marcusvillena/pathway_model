# %%
from modules.viz import MultiExperiment, metric_x_point, devplot
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
grid = MultiExperiment(
    experiment_dirs=[
        'output/2026-01-04_11h15m20s_grid_4a_NBreconstr_gnn_set'
    ],

    keys=['method','encoder_class'],
    out_dir='./experiments/grid_4a_NBreconstr_gnn_set',
    overwrite=True
)

# %%
metric_x_point(
    df=grid.test,
    cols=grid.keys,
    metrics=['mae','nb','kld'],
    figsize=(12,7),
    strip=True,
    sig=True
)
